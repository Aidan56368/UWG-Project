# %% [markdown]
# # Question 1

# %% [markdown]
# Dataset Description:
# I have a dataset that covers the top 50 songs across 73 countries, updated daily. It includes song title, artist, daily rank, country, and other attributes like release date and album details.
#
# Target Variable Analysis:
# I'm focusing on daily rank. This will allow me to see each song's change daily in popularity and help me decide which one is dominate in all 73 countries.
#
# Prediction Goal:
# I want to be able to predict the top song in all 73 countries based on the data I have.

# %% [markdown]
# # Question 2

# %%
import pandas as pd

df = pd.read_csv('universal_top_spotify_songs.csv')

columns_to_drop = ['spotify_id', 'daily_movement', 'weekly_movement', 'album_name', 'time_signature', 'snapshot_date']

df.drop(columns=columns_to_drop, inplace=True)

print(df.head())
# Out:
#                                   name           artists  daily_rank country  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Jung Kook, Latto           1     NaN
# 1                          Si No Estás    iñigo quintero           2     NaN
# 2                               greedy        Tate McRae           3     NaN
# 3                          PERRO NEGRO   Bad Bunny, Feid           4     NaN
# 4                               MONACO         Bad Bunny           5     NaN
#
#    popularity  is_explicit  duration_ms album_release_date  danceability  \
# 0          97         True       184400         2023-07-14         0.802
# 1          98        False       184061         2022-09-23         0.537
# 2          99         True       131872         2023-09-15         0.750
# 3          95         True       162767         2023-10-13         0.911
# 4          96         True       267194         2023-10-13         0.787
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.832   11    -4.107     1       0.0434        0.3110          0.000000
# 1   0.421    5    -8.720     1       0.0285        0.8270          0.000000
# 2   0.733    6    -3.180     0       0.0319        0.2560          0.000000
# 3   0.778    5    -2.248     1       0.2620        0.0887          0.000022
# 4   0.621    4    -5.009     0       0.0680        0.1500          0.000402
#
#    liveness  valence    tempo
# 0    0.0815    0.890  124.997
# 1    0.1380    0.524   98.224
# 2    0.1140    0.844  111.018
# 3    0.1790    0.345   96.057
# 4    0.5800    0.130  139.056

# %%
df = df.sample(n=500, random_state=1).reset_index(drop=True)

categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns
for col in numerical_cols:
    df[col].fillna(df[col].median(), inplace=True)

print(df.isnull().sum())
# Out:
# name                  0
# artists               0
# daily_rank            0
# country               0
# popularity            0
# is_explicit           0
# duration_ms           0
# album_release_date    0
# danceability          0
# energy                0
# key                   0
# loudness              0
# mode                  0
# speechiness           0
# acousticness          0
# instrumentalness      0
# liveness              0
# valence               0
# tempo                 0
# dtype: int64

# %%
import pandas as pd

df = df.sample(n=500, random_state=1).reset_index(drop=True)

initial_rows = df.shape[0]
df.drop_duplicates(inplace=True)
duplicates_dropped = initial_rows - df.shape[0]
print(f"Dropped {duplicates_dropped} duplicate rows.")  

categorical_cols = df.select_dtypes(include=['object']).columns

for col in categorical_cols:
    print(f"Unique values for {col}: {df[col].unique()}")

for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns

for col in numerical_cols:
    df[col].fillna(df[col].median(), inplace=True)

df = pd.get_dummies(df, drop_first=True)
# Out:
# Dropped 9 duplicate rows.
# Unique values for name: ['Isgubhu' 'Komet' 'TOO MUCH' 'Amar De Cor' 'LADY GAGA' 'Sgudi Snyc'
#  'Kuka se on (feat. Isac Elliot)' 'Es un Secreto' 'Sua sattuu'
#  'เจ้าของที่' 'ERE' 'Columbia' 'WHERE SHE GOES' 'Har Dig'
#  'Pakisztáni/popo' 'CCC' '(It Goes Like) Nanana - Edit'
#  'De Me Ksereis Kala' 'OMG' 'EWIGKEIT - REMIX' 'VZHŮRU CELOU NOC'
#  'Sám proti sobě' 'This Is The Life'
#  'Milo J: Bzrp Music Sessions, Vol. 57' 'Face-off' 'BABY NUEVA' 'Manjha'
#  'Nóttin læðist inn' 'Ngiyeza'
#  'Mungkin Aku Tak Penting? (feat. Tish Errda)' 'Cheques' "U CAN'T C ME"
#  'Буревіями' 'fukumean' 'Prada' 'Cruel Summer' 'I Wanna Be Yours' 'DIE'
#  'Bachke Bachke (feat. Yarah)' 'greedy' 'El Amor De Mi Vida' 'ZOK'
#  '9 bis 9 Sped Up (Shirli Version)' 'Like Crazy' 'heikki???' 'VOU 787'
#  'Popular (with Playboi Carti & Madonna) - Music from the HBO Original Series'
#  'With You' 'Tak Segampang Itu' 'Gitme' 'Badass' 'Hey Mor'
#  'ecstacy (slowed)' 'Slow Dancing (Piano Ver.)' 'LOVELY BASTARDS' 'QLONA'
#  'Quien Es Dei V?' 'Elska' 'SEDA' 'Anti-Hero' 'Cry' 'Snooze'
#  'Automotivo Bibi Fogosa' 'Rich Baby Daddy (feat. Sexyy Red & SZA)'
#  'MI EX TENÍA RAZÓN' 'Ne sebep?' 'august' 'MARGINALA' 'Super Shy'
#  'Bertaraf' 'Dreams - 2004 Remaster' 'MADONNA' 'shhhhhhh..' 'Riptide'
#  'Thích Quá Rùi Nà' 'Dance The Night - From Barbie The Album'
#  'Tere Pyaar Mein' 'Başıma Belasın' 'Dil Nu' 'Something in the Orange'
#  'UN PREVIEW' 'LA INOCENTE' 'Tempo' 'Samjho Na'
#  'Smoke (Prod. Dynamicduo, Padi)' 'Si No Estás' 'Esy' 'Raining In Manila'
#  'My Love Mine All Mine' 'Não Vitalício (Nunca Mais) - Ao Vivo'
#  'First Person Shooter (feat. J. Cole)' 'Ползать' 'FREESTYLE 1' 'Tattoo'
#  'Baby Mama' 'Kertoimia Vastaan' 'Království' 'Tadhana' 'Too late'
#  'IDGAF (feat. Yeat)' 'În golul tău' 'Sunset' 'Um Mês E Pouco - Ao Vivo'
#  'Me Porto Bonito' 'Uz Seen' 'One Of Your Girls' 'Космос' 'Still Rollin'
#  'IT GIRL' '3D (feat. Jack Harlow)'
#  'Gelosa (feat. Shiva, Sfera Ebbasta, Guè)' 'Love Song' 'Giving Me'
#  'Erop Of Eronder' 'Strangers' 'Tere Hawaale (From "Laal Singh Chaddha")'
#  '隱形遊樂場' 'Papa' 'Solitaire' 'Seven (feat. Latto) (Explicit Ver.)'
#  'Sprinter' 'วันนี้ปีที่แล้ว' 'רונדלים' 'Holanda' 'Kamlee' 'Que Onda'
#  'Déjala Que Vuelva (feat. Manuel Turizo)' 'Daylight'
#  'верните в моду любовь' 'TULUM' 'FLASHBACK' 'BATICANO'
#  'Chasing That Feeling' 'Малката беля' 'Þú ert' 'PRONTO'
#  'Hayyoda (From "Jawan")' 'Знайди мене' "Venga Pa' Acá" 'BESO'
#  'Обичам те, ти мене - не' 'Tu Buay' 'Fruto' 'BLUEBERRY'
#  'Entre Beso y Beso' 'Slime You Out (feat. SZA)' 'double take' 'Dhundhala'
#  'Gusto feat. Al James' 'DENTRO DA HILUX' 'ביחד' '勇者' 'Rush'
#  'Obapluto (feat. Pa Monday-Edo)' "Не втратимо зв'язок"
#  'Ánh Sao Và Bầu Trời' 'Paint The Town Red' 'Țigancă Balcanică' 'COMMEND'
#  'Para Sa Streets' 'RAGGARBILAR (WARRA WARRA)' 'ETA' 'Aşk Olsun'
#  'Enchanté' 'Nametag' 'Flowers' 'Meridian' 'Seu Brilho Sumiu - Ao Vivo'
#  'WEST AFRICA TIME' 'Hässlich' 'Ko Tau Reikia' 'TELEFONO NUEVO'
#  'Sommerhus' 'Mi Bello Angel' 'Coco Chanel' 'Either Way' 'Según Quién'
#  'GRACIAS POR NADA' 'Mr. Brightside' 'RESTORAN' 'Gode Dage, Gode Drinks'
#  'I Want That' '地球上的最後一朵花' 'Primera Cita' 'vampire' 'Chulo pt.2' 'Lbaroud'
#  'LALA' 'Kolor' 'Jumeirah' 'Eigen Schuld' 'Water' 'Sial' 'HIBIKI'
#  'Das ist Bonez 💀' 'A Psalm of Life' 'NUR DAMIT DU WEISST' 'get him back!'
#  'Grät' '摯友' "Why'd You Only Call Me When You're High?" 'DISPARA ***'
#  'duubel5-v2.mp3' 'Sweater Weather'
#  'uLala Kanjani (feat. LeeMcKrazy & Skandisoul)' 'За малко' 'Kesariya'
#  'Piloto' 'SPIT IN MY FACE!' '7 Dni' 'DANCE FLOOR' 'Ni Una Ni Dos' 'Ghost'
#  'Selamat (Selamat Tinggal)' 'Ты так красива' 'fix net normal' 'FINA'
#  'Slow Dancing' 'Fin de Semana' 'Где ты?' 'KUBOLOR (feat. Amaarae)'
#  'Night Changes' 'Плач' 'Ennen vanhaan' 'Ditto' '地球儀 - Spinning Globe'
#  'Malaika' 'Another Love' 'Josefin' "Guasto D'Amore"
#  'What Was I Made For? [From The Motion Picture "Barbie"]' 'Skupa'
#  'MR. OCTOBER' 'Нямам Теб' 'Mamma Mia' 'CENERE' 'MOJABI GHOST'
#  'Tujhe Kitna Chahne Lage (From "Kabir Singh")' 'Blank Space'
#  'Arranca (feat. Omega)' 'LOS PITS' 'Tá OK' '333' 'Ton Kosmo Girizo'
#  'Insomnia' 'PARANOIA' 'MILANO' 'Tertawan Hati'
#  'STFU (feat. Calin & SIMILIVINLIFE)' 'Noodgeval' 'ME N U'
#  'No Role Modelz' 'You & Me' 'Ordinary Person (From "Leo")' 'Полудях'
#  'TELEKINESIS (feat. SZA & Future)' 'Dark Red'
#  "Can't Hold Us (feat. Ray Dalton)" 'כל הכוכבים' 'Ngilele E Hotel'
#  'SZÍNVAK' 'Asal Mein' 'يمكن خير' 'Stingið henni í steininn'
#  'Dýrð í dauðaþögn' 'Wenn du lächelst' 'Pişman Değilim' 'Shayad'
#  'Long time no see' 'Still Alive' 'METAMORPHOSIS' 'Freed From Desire'
#  'I AM' 'Evergreen' 'Ape Song' '訣愛 (劇集《蒼蘭訣》片頭曲)' 'Kan Inte Gå'
#  'Maan Meri Jaan' 'Loco Loco (feat. Sluwe Ollie)' 'Stroj'
#  'Push Up - Main Edit' 'Lollipop' '500lbs' 'One Dance' 'Mesafe'
#  'Classy 101' 'Naa Ready (From "Leo")' 'Take Two' 'FLECHAZO EN EL CENTRO'
#  'THUNDER Y LIGHTNING' 'UNA NOCHE EN MEDELLÍN - REMIX' 'אף פעם לא לבד'
#  'bad' 'DOG EAT DOG II (feat. Cruel Santino and Bella Shmurda)'
#  'Viva La Vida' 'Basrah w Atooh' 'לצאת מדיכאון' 'Lonely At The Top'
#  'Saan?' 'SULZI' 'MERCEDES CAROTA' 'Skoni' 'Это любовь' 'Somna' 'Always'
#  'Sağlam Kalça' 'El Mambo' 'Nahin Milta' 'ЧАСТУШКА' 'AMARGURA'
#  'ITALODISCO' 'Penas de Antaño' 'Villám' 'Mina Ögon /Ta Matia Moy'
#  '眼淚記得你 - 電影《想見你》主題曲' 'Крепче' 'Ya No Vuelvas (Versión Cuarteto)'
#  'Agora Hills' 'Calling For You (feat. 21 Savage)' 'Царица' 'Khayaal'
#  '295' 'Take it' 'Die For You' 'I KNOW ?' 'Se Grita' 'Tu y Yo' 'un x100to'
#  'EL AMOR DE SU VIDA' 'OCD (feat. Annet X)' 'In deinen Armen' 'Горчиво'
#  'You Proof' 'Desi Kalakaar' 'For Us' 'Y Dor' 'PERRO NEGRO' 'MONACO'
#  'Salgo a Bailar' 'No love' 'CCC - Remix' 'بأمارة مين']
# Unique values for artists: ['Sam Deep, Njelic, Aymos' 'Udo Lindenberg, Apache 207'
#  'The Kid LAROI, Jung Kook, Central Cee' 'Van Zee'
#  'Peso Pluma, Gabito Ballesteros, Junior H'
#  'De Mthuda, Da Muziqal Chef, Eemoh' 'Cledos, Isac Elliot' 'Plan B'
#  'Mirella' 'Mirrr' 'juan karlos' 'Quevedo' 'Bad Bunny' 'Yasin'
#  'DESH, Young Fly' 'Michelle Maciel, Eden Muñoz' 'Peggy Gou'
#  'Wang, DJ Cron, Mateos Nps' 'NewJeans' 'erobé, KXXMA, Lyfrix'
#  'P T K, Viktor Sheen' 'Viktor Sheen' 'Amy Macdonald' 'Bizarrap, Milo j'
#  'Jimin' 'Vishal Mishra' 'Hafdís Huld' 'Lwah Ndlunkulu'
#  'Luqman Podolski, Tish Errda' 'Shubh' 'reezy' 'SHUMEI, ZLATA OGNEVICH'
#  'Gunna' 'cassö, RAYE, D-Block Europe' 'Taylor Swift' 'Arctic Monkeys'
#  'Gazo' 'Karan Aujla, Ikky, Yarah' 'Tate McRae'
#  'Los Ángeles Azules, Maria Becerra' 'Bo9al' 'SIRA, Bausa, badchieff'
#  'nublu' 'The Weeknd, Playboi Carti, Madonna' 'AP Dhillon' 'Anggi Marito'
#  'Reynmen' 'Anirudh Ravichander' 'Ozuna, Feid' 'SUICIDAL-IDOL' 'V'
#  'ZWE1HVNDXR, yatashigang' 'KAROL G, Peso Pluma' 'Dei V'
#  'Daniil, Lil Binni' 'Bad Bunny, Bryant Myers' 'Cigarettes After Sex'
#  'SZA' 'Bibi Babydoll, Dj Brunin XM, KZA Produções'
#  'Drake, Sexyy Red, SZA' 'KAROL G' 'Sadraddin' 'Mom4eto, Dimoff'
#  'Canbay & Wolker, Heijan, Muti' 'Fleetwood Mac' 'Roi 6/12' 'WEAN, tlinh'
#  'Vance Joy' 'tlinh, Trung Trần' 'Dua Lipa'
#  'Pritam, Arijit Singh, Amitabh Bhattacharya, Nikhita Gandhi'
#  'Aleyna Tilki' 'AP Dhillon, Shinda Kahlon' 'Zach Bryan' 'Mora, Feid'
#  'Aditya Rikhari' 'Dynamicduo, Lee Young Ji' 'iñigo quintero' 'Light'
#  'Lola Amour' 'Mitski' 'Matheus & Kauan, Mari Fernandez' 'Drake, J. Cole'
#  'LSP' 'Dimoff' 'OFFICIAL HIGE DANDISM' 'Don Pero' 'Jami Faltin'
#  'Up Dharma Down' 'Nitro, Madame' 'Drake, Yeat' 'The Motans, RAVA'
#  'Separ, Jerry Lee, P T K' 'Zé Neto & Cristiano'
#  'Bad Bunny, Chencho Corleone' 'Singapūras Satīns, A-Europa' 'Troye Sivan'
#  'Skryptonite, Charusha' "Aliyah's Interlude" 'Jung Kook, Jack Harlow'
#  'Finesse, Shiva, Sfera Ebbasta, Guè' 'マルシィ' 'Jazzy' 'Pommelien Thijs'
#  'Kenya Grace' 'Pritam, Arijit Singh, Shilpa Rao' 'Hins Cheung'
#  'DESH, Azahriah' 'Werenoi' 'Jung Kook, Latto' 'Dave, Central Cee' 'MEYOU'
#  'Static' 'Jhayco' 'SARRB, Starboy X'
#  'Calle 24, Chino Pacas, Fuerza Regida' 'Piso 21, Manuel Turizo'
#  'David Kushner' 'две тысячи ярдов' 'Peso Pluma, Grupo Frontera'
#  'Favé, Gazo' 'TOMORROW X TOGETHER' 'Djordan' 'Tugan, Ortiz, Skoul'
#  'Anirudh Ravichander, Priya Mali' 'Klavdia Petrivna' 'Pailita, Fran C'
#  'ROSALÍA, Rauw Alejandro' 'Medi' 'Valentino GRM, SMILE BEATS'
#  'Guzior, Favst' 'Ke Personajes' 'Drake, SZA' 'dhruv'
#  'Yashraj, Dropped Out, Talwiinder' 'Zack Tabudlo, Al James'
#  'Luan Pereira, MC Ryan SP, Mc Daniel' 'Marina Maximilian, Guy Mentesh'
#  'YOASOBI' 'Shallipopi, Pa Monday-Edo' 'alyona alyona' 'T.R.I' 'Doja Cat'
#  'Tzanca Uraganu, Manele Mentolate' 'ODUMODUBLVCK' 'Hev Abi'
#  'Rasmus Gozzi, FRÖKEN SNUSK, DANJAL' 'cakal' 'Sosa La M'
#  'Taco Hemingway, Oki, schafter, @atutowy' 'Miley Cyrus' 'Dave, Tiakola'
#  'Israel & Rodolffo, Mari Fernandez' 'A-Reece, M.anifest' 'AYLIVA'
#  'Adrina, Hypocrite' 'Bad Bunny, Luar La L' 'Marstein' 'Natanael Cano'
#  'Eladio Carrion, Bad Bunny' 'IVE' 'Maluma, Carin Leon' 'The Killers'
#  'Motive' 'Lamin' '(G)I-DLE' '陳卓賢 Ian' 'Carin Leon' 'Olivia Rodrigo'
#  'Bad Gyal, Tokischa, Young Miko' 'Draganov, Inkonnu' 'Myke Towers'
#  'Gibbs, Frank Leen, Jonatan' 'ICEKIID, Artigeardit' 'Metejoor' 'Tyla'
#  'Mahalini' 'Bad Bunny, Mora' 'Bonez MC' 'Lim Young Woong' 'Hov1' 'A-Lin'
#  'Nicki Nicole, Milo j' 'The Neighbourhood'
#  'Dj Jaivane, LeeMcKrazy, Skandisoul' 'DENIS TEOFIKOV, Dessita'
#  'Pritam, Arijit Singh, Amitabh Bhattacharya' 'Flora Matos' 'ThxSoMch'
#  'Molec' 'NEWLIGHTCHILD' 'BM' 'Justin Bieber' 'Virgoun, Audy'
#  'Quest Pistols' 'AUT of ORDA' 'Bad Bunny, Young Miko'
#  'Oscar Maydon, Junior H' 'Gio Pika' 'ODUMODUBLVCK, Amaarae'
#  'One Direction' 'TUMAZAR, Кажанна' 'Costi' 'Kenshi Yonezu' 'Ant Wan'
#  'Tom Odell' 'Delara' 'Bresh, SHUNE' 'Billie Eilish' 'MBT'
#  'Ivayla, Ilian Boyd' 'Mentissa' 'Lazza' 'Tainy, Bad Bunny'
#  'Arijit Singh, Mithoon' 'Becky G, Omega' 'DENNIS, MC Kevin o Chris'
#  'Cris Mj, Yan Block' 'Bloody Hawk' 'Trap19 Connection, Kotenceto'
#  'HEARTSTEEL, League of Legends, BAEKHYUN, tobi lou, ØZI, Cal Scruby'
#  'BIA, Sfera Ebbasta, Fivio Foreign' 'Awdella'
#  'STEIN27, Calin, SIMILIVINLIFE' 'Goldband' 'RACK, Sin Laurent' 'J. Cole'
#  'JENNIE' 'Anirudh Ravichander, Nikhita Gandhi' 'Alisia, Toni Storaro'
#  'Travis Scott, SZA, Future' 'Steve Lacy'
#  'Macklemore & Ryan Lewis, Macklemore, Ryan Lewis, Ray Dalton' 'Tuna'
#  'Killorbeezbeatz' 'VALMAR' 'Darshan Raval' 'Ramy Sabry' 'ICEGUYS' 'BRÍET'
#  'Milano' 'Semicenk, Doğu Swag' 'Pritam, Arijit Singh'
#  'Taimour Baig, Raffey Anwar, AUR' 'Raste' 'INTERWORLD' 'Gala'
#  'Richy Mitch & The Coal Miners' '詹雯婷' 'Bolaget' 'King'
#  'Alessio, Sluwe Ollie' 'Peter Pann, Kali, Separ' 'Creeds' 'Darell'
#  'Lil Tecca' 'Drake, Wizkid, Kyla' 'Semicenk' 'Feid, Young Miko'
#  'Anirudh Ravichander, Thalapathy Vijay, Asal Kolaar' 'BTS'
#  'YSY A, Bhavi, Milo j' 'Bad Bunny, Eladio Carrion'
#  'KAROL G, Cris Mj, Ryan Castro' 'Inbal Bibi' 'wave to earth'
#  'ODUMODUBLVCK, Cruel Santino, Bella Shmurda' 'Coldplay' 'Cairokee'
#  'יגל אושרי' 'Asake' 'Maki' 'V:RGO, FYRE, Yoana Sashova'
#  'Bad Bunny, YOVNGCHIMI' 'TOQUEL' 'Skryptonite'
#  'Humlan Djojj, Josefine Götestam' 'Daniel Caesar' 'Borqy' 'Kiko Rivera'
#  'Bayaan' 'Karna.val' 'The Kolors' 'Mihályfi Luca, Ekhoe'
#  'Nineb Youk, TOQUEL, Jo Lids' 'Shi Shi' 'KRBK'
#  "Luck Ra, La K'onga, Ke Personajes" 'Drake, 21 Savage' 'ANNA ASTI'
#  'Talwiinder, NDS' 'Sidhu Moose Wala' 'Jazeek' 'The Weeknd' 'Travis Scott'
#  'Morad, Jul' 'LA NUEVA ESCUELA' 'Grupo Frontera, Bad Bunny'
#  'Grupo Frontera, Grupo Firme' 'Viktor Sheen, Annet X' 'Galena'
#  'Morgan Wallen' 'Yo Yo Honey Singh' 'Soolking, Unleaded, DYSTINCT'
#  'Bad Bunny, Feid' 'FMK, Emilia' 'Ninho, Ayra Starr'
#  'Michelle Maciel, Eden Muñoz, Panter Bélico' 'Farid']
# Unique values for country: ['ZA' 'AT' 'SA' 'PT' 'EC' 'FI' 'CO' 'TH' 'AE' 'DO' 'PE' 'SE' 'HU' 'MX'
#  'CH' 'GR' 'SG' 'SK' 'VE' 'KR' 'SV' 'IN' 'IS' 'HN' 'MY' 'PK' 'LU' 'UA'
#  'LV' 'IE' 'FR' 'DK' 'UY' 'MA' 'VN' 'EE' 'CR' 'KZ' 'TR' 'GT' 'ES' 'NZ'
#  'GB' 'BO' 'PH' 'BG' 'BE' 'AU' 'PA' 'BR' 'BY' 'JP' 'IT' 'CZ' 'RO' 'HK'
#  'CA' 'IL' 'PY' 'LT' 'PL' 'CL' 'NO' 'AR' 'NG' 'DE' 'US' 'ID' 'TW' 'NI'
#  'NL' 'EG']
# Unique values for album_release_date: ['2023-10-13' '2023-01-19' '2023-10-19' '2023-07-28' '2023-06-29'
#  '2023-05-19' '2023-10-06' '2010-07-20' '2022-03-24' '2023-09-22'
#  '2023-07-07' '2023-02-28' '2023-07-21' '2023-05-04' '2023-06-15'
#  '2023-06-21' '2023-01-02' '2023-06-23' '2023-10-01' '2007-01-01'
#  '2023-10-03' '2023-03-24' '2020-03-17' '2012-06-04' '2023-01-18'
#  '2023-03-03' '2023-10-20' '2023-04-17' '2023-06-16' '2023-08-11'
#  '2019-08-23' '2013-09-09' '2022-07-01' '2023-08-18' '2023-09-15'
#  '2023-07-29' '2023-07-06' '2023-08-24' '2023-06-02' '2022-12-02'
#  '2023-09-01' '2022-10-07' '2023-06-06' '2023-09-08' '2023-08-25'
#  '2023-08-10' '2023-03-17' '2023-08-03' '2022-10-21' '2019-10-25'
#  '2022-12-09' '2023-02-18' '2020-07-24' '2023-07-24' '2023-09-29'
#  '1977-02-04' '2023-10-02' '2023-10-07' '2014-09-09' '2023-07-14'
#  '2023-05-25' '2023-02-01' '2022-04-22' '2022-04-01' '2020-02-12'
#  '2022-02-10' '2023-09-05' '2022-09-23' '2023-06-30' '2023-06-14'
#  '2017-04-28' '2023-01-08' '2023-04-21' '2022-10-27' '2012-12-07'
#  '2023-10-10' '2023-01-12' '2023-03-31' '2023-06-22' '2022-05-06'
#  '2022-07-04' '2015-03-16' '2023-09-30' '2023-02-24' '2023-09-27'
#  '2023-03-10' '2022-08-04' '2023-04-20' '2022-10-25' '2022-10-28'
#  '2023-06-01' '2023-02-22' '2023-08-30' '2018-05-11' '2023-04-14'
#  '2023-04-25' '2023-03-15' '2022-12-01' '2023-08-14' '2023-04-15'
#  '2023-07-25' '2023-09-11' '2023-10-04' '2020-12-04' '2022-01-21'
#  '2022-02-18' '2023-05-26' '2021-08-23' '2023-04-13' '2021-09-10'
#  '2023-09-20' '2023-07-27' '2023-01-13' '2023-06-09' '2023-09-21'
#  '2023-03-02' '2023-05-09' '2023-09-25' '2004-01-01' '2022-09-02'
#  '2022-10-31' '2022-04-29' '2023-03-23' '2023-10-24' '2023-05-12'
#  '2023-01-23' '2022-05-02' '2022-04-08' '2023-05-18' '2013-04-19'
#  '2023-07-19' '2022-10-06' '2018-06-12' '2022-12-20' '2022-03-03'
#  '2023-06-28' '2021-03-19' '2019-06-17' '2022-10-23' '2023-10-12'
#  '2014-11-17' '2023-10-16' '2022-12-19' '2023-07-17' '2021-02-25'
#  '2013-06-24' '2023-06-07' '2023-01-27' '2023-07-13' '2021-05-01'
#  '2022-11-18' '2022-04-07' '2019-05-31' '2014-10-27' '2023-09-28'
#  '2023-10-23' '2021-08-13' '2014-12-09' '2017-02-20' '2012-10-09'
#  '2021-12-17' '2023-08-28' '2022-10-26' '2020-02-18' '2023-01-11'
#  '2022-08-16' '2020-02-14' '2023-07-16' '2023-04-28' '2021-11-25'
#  '1997-11-17' '2023-04-10' '2017-05-17' '2022-08-15' '2021-12-29'
#  '2022-10-12' '2016-05-06' '2023-09-06' '2023-06-20' '2008-05-26'
#  '2023-08-15' '2022-05-27' '2015-01-01' '2020-10-30' '2023-04-07'
#  '2023-08-04' '2019-02-01' '2023-05-05' '2022-12-23' '2016-01-05'
#  '2023-03-16' '2021-05-15' '2016-11-24' '2022-12-30' '2023-06-04'
#  '2014-09-26' '2023-08-31' '2022-06-21']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("DataFrame columns:", df.columns)

numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

print("Numeric columns:", numeric_columns)

for column in numeric_columns:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=df.loc[:, column]) 
    plt.title(column)
    plt.show()
# Out:
# DataFrame columns: Index(['daily_rank', 'popularity', 'is_explicit', 'duration_ms',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        ...
#        'album_release_date_2023-10-06', 'album_release_date_2023-10-07',
#        'album_release_date_2023-10-10', 'album_release_date_2023-10-12',
#        'album_release_date_2023-10-13', 'album_release_date_2023-10-16',
#        'album_release_date_2023-10-19', 'album_release_date_2023-10-20',
#        'album_release_date_2023-10-23', 'album_release_date_2023-10-24'],
#       dtype='object', length=932)
# Numeric columns: Index(['daily_rank', 'popularity', 'duration_ms', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo'],
#       dtype='object')

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

outliers_removed = {} 

for column in numeric_columns:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5*IQR
    upper_bound = Q3 + 1.5*IQR
    
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    
    outliers_removed[column] = outliers
    
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

for column, outlier_df in outliers_removed.items():
    if not outlier_df.empty:
        print(f"Outliers removed for {column}:")
        display(outlier_df)
# Out:
# Outliers removed for popularity:
#      daily_rank  popularity  is_explicit  duration_ms  danceability  energy  \
# 167          49           6        False       182400         0.641   0.449
# 174          12           4        False       170605         0.815   0.923
# 347          41          15        False       199120         0.425   0.730
#
#      key  loudness  mode  speechiness  ...  album_release_date_2023-10-06  \
# 167    5    -9.568     0       0.1620  ...                              0
# 174    6    -3.753     0       0.0875  ...                              0
# 347    4    -9.038     1       0.0546  ...                              0
#
#      album_release_date_2023-10-07  album_release_date_2023-10-10  \
# 167                              0                              0
# 174                              0                              0
# 347                              0                              0
#
#      album_release_date_2023-10-12  album_release_date_2023-10-13  \
# 167                              0                              0
# 174                              0                              0
# 347                              0                              0
#
#      album_release_date_2023-10-16  album_release_date_2023-10-19  \
# 167                              0                              0
# 174                              0                              0
# 347                              0                              0
#
#      album_release_date_2023-10-20  album_release_date_2023-10-23  \
# 167                              0                              0
# 174                              0                              0
# 347                              0                              0
#
#      album_release_date_2023-10-24
# 167                              0
# 174                              0
# 347                              0
#
# [3 rows x 932 columns]
# Outliers removed for duration_ms:
#      daily_rank  popularity  is_explicit  duration_ms  danceability  energy  \
# 0             7          47        False       413838         0.822   0.571
# 5            19          66        False       331377         0.813   0.399
# 126          32          78        False       346290         0.589   0.522
# 199          14          89         True       354784         0.619   0.619
# 207          38          89         True       354784         0.619   0.619
# 245          39          61        False       347245         0.874   0.405
# 319          21          89         True       354784         0.619   0.619
# 333          50          90         True       353754         0.458   0.535
# 478           6          89         True       354784         0.619   0.619
# 493          43          86         True       354784         0.619   0.619
#
#      key  loudness  mode  speechiness  ...  album_release_date_2023-10-06  \
# 0      1   -11.215     0       0.0527  ...                              0
# 5      0   -18.875     1       0.0826  ...                              0
# 126    9   -10.649     1       0.0391  ...                              0
# 199    2    -6.238     1       0.4910  ...                              0
# 207    2    -6.238     1       0.4910  ...                              0
# 245   11   -11.942     1       0.0568  ...                              0
# 319    2    -6.238     1       0.4910  ...                              0
# 333    5    -4.854     0       0.0281  ...                              0
# 478    2    -6.238     1       0.4910  ...                              0
# 493    2    -6.238     1       0.4910  ...                              0
#
#      album_release_date_2023-10-07  album_release_date_2023-10-10  \
# 0                                0                              0
# 5                                0                              0
# 126                              0                              0
# 199                              0                              0
# 207                              0                              0
# 245                              0                              0
# 319                              0                              0
# 333                              0                              0
# 478                              0                              0
# 493                              0                              0
#
#      album_release_date_2023-10-12  album_release_date_2023-10-13  \
# 0                                0                              1
# 5                                0                              0
# 126                              0                              0
# 199                              0                              1
# 207                              0                              1
# 245                              0                              0
# 319                              0                              1
# 333                              0                              0
# 478                              0                              1
# 493                              0                              1
#
#      album_release_date_2023-10-16  album_release_date_2023-10-19  \
# 0                                0                              0
# 5                                0                              0
# 126                              0                              0
# 199                              0                              0
# 207                              0                              0
# 245                              0                              0
# 319                              0                              0
# 333                              0                              0
# 478                              0                              0
# 493                              0                              0
#
#      album_release_date_2023-10-20  album_release_date_2023-10-23  \
# 0                                0                              0
# 5                                0                              0
# 126                              0                              0
# 199                              0                              0
# 207                              0                              0
# 245                              0                              0
# 319                              0                              0
# 333                              0                              0
# 478                              0                              0
# 493                              0                              0
#
#      album_release_date_2023-10-24
# 0                                0
# 5                                0
# 126                              0
# 199                              0
# 207                              0
# 245                              0
# 319                              0
# 333                              0
# 478                              0
# 493                              0
#
# [10 rows x 932 columns]
# Outliers removed for danceability:
#      daily_rank  popularity  is_explicit  duration_ms  danceability  energy  \
# 232          45          57        False       233360         0.279   0.515
# 287          28          69        False       214187         0.263   0.182
#
#      key  loudness  mode  speechiness  ...  album_release_date_2023-10-06  \
# 232    7    -4.511     1       0.0305  ...                              0
# 287    8   -11.414     0       0.0337  ...                              0
#
#      album_release_date_2023-10-07  album_release_date_2023-10-10  \
# 232                              0                              0
# 287                              0                              0
#
#      album_release_date_2023-10-12  album_release_date_2023-10-13  \
# 232                              0                              0
# 287                              0                              0
#
#      album_release_date_2023-10-16  album_release_date_2023-10-19  \
# 232                              0                              0
# 287                              0                              0
#
#      album_release_date_2023-10-20  album_release_date_2023-10-23  \
# 232                              0                              0
# 287                              0                              0
#
#      album_release_date_2023-10-24
# 232                              0
# 287                              0
#
# [2 rows x 932 columns]
# Outliers removed for energy:
#      daily_rank  popularity  is_explicit  duration_ms  danceability  energy  \
# 27           30          45        False       182090         0.716  0.1240
# 84           10          91        False       228013         0.369  0.1920
# 150          38          45        False       135325         0.581  0.1900
# 240          13          91        False       228013         0.369  0.1920
# 247          17          90        False       228013         0.369  0.1920
# 290          22          96        False       222369         0.444  0.0911
# 386          29          96        False       222369         0.444  0.0911
# 421          35          67        False       160373         0.323  0.0736
#
#      key  loudness  mode  speechiness  ...  album_release_date_2023-10-06  \
# 27     0   -12.602     1       0.0394  ...                              0
# 84     4   -12.151     0       0.0400  ...                              0
# 150    7   -13.840     1       0.0310  ...                              0
# 240    4   -12.151     0       0.0400  ...                              0
# 247    4   -12.151     0       0.0400  ...                              0
# 290    0   -17.665     1       0.0307  ...                              0
# 386    0   -17.665     1       0.0307  ...                              0
# 421    0   -15.555     1       0.0371  ...                              0
#
#      album_release_date_2023-10-07  album_release_date_2023-10-10  \
# 27                               0                              0
# 84                               0                              0
# 150                              0                              0
# 240                              0                              0
# 247                              0                              0
# 290                              0                              0
# 386                              0                              0
# 421                              0                              0
#
#      album_release_date_2023-10-12  album_release_date_2023-10-13  \
# 27                               0                              0
# 84                               0                              0
# 150                              0                              0
# 240                              0                              0
# 247                              0                              0
# 290                              0                              0
# 386                              0                              0
# 421                              0                              0
#
#      album_release_date_2023-10-16  album_release_date_2023-10-19  \
# 27                               0                              0
# 84                               0                              0
# 150                              0                              0
# 240                              0                              0
# 247                              0                              0
# 290                              0                              0
# 386                              0                              0
# 421                              0                              0
#
#      album_release_date_2023-10-20  album_release_date_2023-10-23  \
# 27                               0                              0
# 84                               0                              0
# 150                              0                              0
# 240                              0                              0
# 247                              0                              0
# 290                              0                              0
# 386                              0                              0
# 421                              0                              0
#
#      album_release_date_2023-10-24
# 27                               0
# 84                               0
# 150                              0
# 240                              0
# 247                              0
# 290                              0
# 386                              0
# 421                              0
#
# [8 rows x 932 columns]
# Outliers removed for loudness:
#      daily_rank  popularity  is_explicit  duration_ms  danceability  energy  \
# 88            2          68        False       188735         0.686   0.238
# 89           19          75        False       172408         0.744   0.328
# 96            9          94        False       137773         0.504   0.308
# 104           2          65         True       190588         0.804   0.518
# 105          29          77        False       222446         0.685   0.322
# 116          33          62        False       227691         0.522   0.492
# 176          42          66        False       260571         0.662   0.205
# 321           4          78         True       194675         0.800   0.429
# 352          23          67        False       218600         0.813   0.343
# 356          35          88         True       142839         0.593   0.641
# 367          16          60         True       144000         0.684   0.535
# 426          23          69        False       285656         0.325   0.378
# 442          36          95        False       137773         0.504   0.308
# 447          44          65        False       120111         0.769   0.310
# 462           8          95        False       137773         0.504   0.308
#
#      key  loudness  mode  speechiness  ...  album_release_date_2023-10-06  \
# 88     5   -14.540     1       0.2790  ...                              0
# 89     0   -12.535     1       0.2310  ...                              0
# 96     9   -14.958     1       0.0321  ...                              0
# 104   10   -12.733     0       0.1150  ...                              0
# 105    6   -13.200     1       0.0369  ...                              0
# 116    0   -12.356     0       0.1650  ...                              0
# 176    5   -14.005     0       0.0349  ...                              0
# 321    1   -13.439     1       0.2810  ...                              0
# 352    1   -12.647     1       0.2750  ...                              0
# 356    7   -12.727     0       0.0992  ...                              0
# 367    1   -12.376     1       0.2350  ...                              0
# 426   10   -12.695     1       0.0436  ...                              0
# 442    9   -14.958     1       0.0321  ...                              0
# 447    9   -14.249     0       0.3720  ...                              0
# 462    9   -14.958     1       0.0321  ...                              0
#
#      album_release_date_2023-10-07  album_release_date_2023-10-10  \
# 88                               0                              0
# 89                               0                              0
# 96                               0                              0
# 104                              0                              0
# 105                              0                              0
# 116                              0                              0
# 176                              0                              0
# 321                              0                              0
# 352                              0                              0
# 356                              0                              0
# 367                              0                              0
# 426                              0                              0
# 442                              0                              0
# 447                              0                              0
# 462                              0                              0
#
#      album_release_date_2023-10-12  album_release_date_2023-10-13  \
# 88                               0                              0
# 89                               0                              0
# 96                               0                              0
# 104                              0                              1
# 105                              0                              0
# 116                              0                              0
# 176                              0                              0
# 321                              0                              0
# 352                              0                              0
# 356                              0                              0
# 367                              0                              1
# 426                              0                              0
# 442                              0                              0
# 447                              0                              0
# 462                              0                              0
#
#      album_release_date_2023-10-16  album_release_date_2023-10-19  \
# 88                               0                              0
# 89                               0                              0
# 96                               0                              0
# 104                              0                              0
# 105                              0                              0
# 116                              0                              0
# 176                              0                              0
# 321                              0                              0
# 352                              0                              0
# 356                              0                              0
# 367                              0                              0
# 426                              0                              0
# 442                              0                              0
# 447                              0                              0
# 462                              0                              0
#
#      album_release_date_2023-10-20  album_release_date_2023-10-23  \
# 88                               0                              0
# 89                               0                              0
# 96                               0                              0
# 104                              0                              0
# 105                              0                              0
# 116                              0                              0
# 176                              0                              0
# 321                              0                              0
# 352                              0                              0
# 356                              0                              0
# 367                              0                              0
# 426                              0                              0
# 442                              0                              0
# 447                              0                              0
# 462                              0                              0
#
#      album_release_date_2023-10-24
# 88                               0
# 89                               0
# 96                               0
# 104                              0
# 105                              0
# 116                              0
# 176                              0
# 321                              0
# 352                              0
# 356                              0
# 367                              0
# 426                              0
# 442                              0
# 447                              0
# 462                              0
#
# [15 rows x 932 columns]
# Outliers removed for speechiness:
#      daily_rank  popularity  is_explicit  duration_ms  danceability  energy  \
# 13           29          68         True       202954         0.562   0.430
# 43           24          57         True       183878         0.890   0.629
# 54           43          88        False       196600         0.901   0.589
# 57           17          88         True       116104         0.613   0.810
# 58            5          94         True       172797         0.841   0.738
# 59           17          81         True       162244         0.557   0.744
# 92           41          77        False       209546         0.768   0.818
# 97           45          69        False       169835         0.418   0.925
# 98           41          90         True       247444         0.470   0.640
# 100          27          49         True       121315         0.910   0.636
# 109          41          59         True       155520         0.762   0.805
# 151          13          63         True       186239         0.841   0.491
# 159          45          51        False       138653         0.628   0.696
# 193          43          56         True       243134         0.596   0.717
# 211          38          71         True       154305         0.614   0.455
# 212          47          61        False       140089         0.789   0.703
# 255           5          90         True       247444         0.470   0.640
# 256          32          50        False       229333         0.597   0.710
# 267           4          90         True       216327         0.847   0.724
# 284          18          69        False       189183         0.639   0.522
# 311          24          87         True       250851         0.751   0.669
# 328          28          91         True       292799         0.690   0.521
# 353          46          88        False       196600         0.901   0.589
# 354          40          69        False       169835         0.418   0.925
# 375          13          70         True       165694         0.827   0.664
# 394          31          56         True       243134         0.596   0.717
# 428           6          91         True       247444         0.470   0.640
# 445           6          94         True       172797         0.841   0.738
# 446          18          82         True       162244         0.557   0.744
# 459          21          94         True       172797         0.841   0.738
# 479          39          91         True       247444         0.470   0.640
# 491          49          61        False       140089         0.789   0.703
# 492          21          75         True       202186         0.668   0.436
# 497          38          90         True       247444         0.470   0.640
#
#      key  loudness  mode  speechiness  ...  album_release_date_2023-10-06  \
# 13     5   -11.255     0        0.449  ...                              0
# 43     8    -7.930     1        0.445  ...                              0
# 54     1    -6.713     0        0.289  ...                              0
# 57     1    -6.160     1        0.488  ...                              0
# 58     7    -7.455     0        0.307  ...                              0
# 59     1    -4.180     1        0.344  ...                              0
# 92    11    -4.057     0        0.328  ...                              0
# 97     1    -2.941     1        0.385  ...                              0
# 98     2    -7.779     1        0.320  ...                              1
# 100    9   -10.310     1        0.651  ...                              0
# 109    1    -6.630     1        0.386  ...                              0
# 151    7    -9.141     1        0.337  ...                              0
# 159    9    -5.955     0        0.402  ...                              0
# 193   11    -7.679     0        0.369  ...                              0
# 211    4   -10.389     0        0.293  ...                              0
# 212    0    -7.401     1        0.367  ...                              0
# 255    2    -7.779     1        0.320  ...                              1
# 256    0    -5.706     0        0.402  ...                              0
# 267    1    -5.410     1        0.298  ...                              0
# 284    6    -6.733     1        0.434  ...                              0
# 311    7    -5.367     1        0.445  ...                              0
# 328   10    -8.492     0        0.339  ...                              0
# 353    1    -6.713     0        0.289  ...                              0
# 354    1    -2.941     1        0.385  ...                              0
# 375    1    -5.848     1        0.305  ...                              0
# 394   11    -7.679     0        0.369  ...                              0
# 428    2    -7.779     1        0.320  ...                              1
# 445    7    -7.455     0        0.307  ...                              0
# 446    1    -4.180     1        0.344  ...                              0
# 459    7    -7.455     0        0.307  ...                              0
# 479    2    -7.779     1        0.320  ...                              1
# 491    0    -7.401     1        0.367  ...                              0
# 492    8    -7.932     0        0.391  ...                              0
# 497    2    -7.779     1        0.320  ...                              1
#
#      album_release_date_2023-10-07  album_release_date_2023-10-10  \
# 13                               0                              0
# 43                               0                              0
# 54                               0                              0
# 57                               0                              0
# 58                               0                              0
# 59                               0                              0
# 92                               0                              0
# 97                               0                              0
# 98                               0                              0
# 100                              0                              0
# 109                              0                              0
# 151                              0                              0
# 159                              0                              0
# 193                              0                              0
# 211                              0                              0
# 212                              0                              0
# 255                              0                              0
# 256                              0                              0
# 267                              0                              0
# 284                              0                              0
# 311                              0                              0
# 328                              0                              0
# 353                              0                              0
# 354                              0                              0
# 375                              0                              0
# 394                              0                              0
# 428                              0                              0
# 445                              0                              0
# 446                              0                              0
# 459                              0                              0
# 479                              0                              0
# 491                              0                              0
# 492                              0                              0
# 497                              0                              0
#
#      album_release_date_2023-10-12  album_release_date_2023-10-13  \
# 13                               0                              0
# 43                               0                              0
# 54                               0                              0
# 57                               0                              0
# 58                               0                              0
# 59                               0                              0
# 92                               0                              0
# 97                               0                              0
# 98                               0                              0
# 100                              0                              0
# 109                              0                              0
# 151                              0                              0
# 159                              0                              0
# 193                              0                              0
# 211                              0                              0
# 212                              0                              0
# 255                              0                              0
# 256                              0                              0
# 267                              0                              1
# 284                              0                              0
# 311                              0                              1
# 328                              0                              0
# 353                              0                              0
# 354                              0                              0
# 375                              0                              0
# 394                              0                              0
# 428                              0                              0
# 445                              0                              0
# 446                              0                              0
# 459                              0                              0
# 479                              0                              0
# 491                              0                              0
# 492                              0                              0
# 497                              0                              0
#
#      album_release_date_2023-10-16  album_release_date_2023-10-19  \
# 13                               0                              0
# 43                               0                              0
# 54                               0                              0
# 57                               0                              0
# 58                               0                              0
# 59                               0                              0
# 92                               0                              0
# 97                               0                              0
# 98                               0                              0
# 100                              0                              0
# 109                              0                              0
# 151                              0                              0
# 159                              0                              0
# 193                              0                              0
# 211                              0                              0
# 212                              0                              0
# 255                              0                              0
# 256                              0                              0
# 267                              0                              0
# 284                              0                              0
# 311                              0                              0
# 328                              0                              0
# 353                              0                              0
# 354                              0                              0
# 375                              0                              0
# 394                              0                              0
# 428                              0                              0
# 445                              0                              0
# 446                              0                              0
# 459                              0                              0
# 479                              0                              0
# 491                              0                              0
# 492                              0                              0
# 497                              0                              0
#
#      album_release_date_2023-10-20  album_release_date_2023-10-23  \
# 13                               0                              0
# 43                               0                              0
# 54                               0                              0
# 57                               0                              0
# 58                               0                              0
# 59                               0                              0
# 92                               0                              0
# 97                               0                              0
# 98                               0                              0
# 100                              0                              0
# 109                              0                              0
# 151                              0                              0
# 159                              0                              0
# 193                              1                              0
# 211                              0                              0
# 212                              0                              0
# 255                              0                              0
# 256                              0                              0
# 267                              0                              0
# 284                              0                              0
# 311                              0                              0
# 328                              0                              0
# 353                              0                              0
# 354                              0                              0
# 375                              0                              0
# 394                              1                              0
# 428                              0                              0
# 445                              0                              0
# 446                              0                              0
# 459                              0                              0
# 479                              0                              0
# 491                              0                              0
# 492                              0                              0
# 497                              0                              0
#
#      album_release_date_2023-10-24
# 13                               0
# 43                               0
# 54                               0
# 57                               0
# 58                               0
# 59                               0
# 92                               0
# 97                               0
# 98                               0
# 100                              0
# 109                              0
# 151                              0
# 159                              0
# 193                              0
# 211                              0
# 212                              0
# 255                              0
# 256                              0
# 267                              0
# 284                              0
# 311                              0
# 328                              0
# 353                              0
# 354                              0
# 375                              0
# 394                              0
# 428                              0
# 445                              0
# 446                              0
# 459                              0
# 479                              0
# 491                              0
# 492                              0
# 497                              0
#
# [34 rows x 932 columns]
# Outliers removed for acousticness:
#      daily_rank  popularity  is_explicit  duration_ms  danceability  energy  \
# 229          32          79        False       243724         0.562   0.433
# 235          27          67        False       194394         0.703   0.369
# 253          12          82        False       197538         0.789   0.642
# 276          44          89        False       226600         0.672   0.520
#
#      key  loudness  mode  speechiness  ...  album_release_date_2023-10-06  \
# 229    2    -6.785     1       0.0397  ...                              0
# 235    3    -8.697     1       0.0640  ...                              0
# 253    0    -8.631     0       0.0379  ...                              0
# 276    8    -7.747     1       0.0353  ...                              0
#
#      album_release_date_2023-10-07  album_release_date_2023-10-10  \
# 229                              0                              0
# 235                              0                              0
# 253                              0                              0
# 276                              0                              0
#
#      album_release_date_2023-10-12  album_release_date_2023-10-13  \
# 229                              0                              0
# 235                              0                              0
# 253                              0                              0
# 276                              0                              0
#
#      album_release_date_2023-10-16  album_release_date_2023-10-19  \
# 229                              0                              0
# 235                              0                              0
# 253                              0                              0
# 276                              0                              0
#
#      album_release_date_2023-10-20  album_release_date_2023-10-23  \
# 229                              0                              0
# 235                              0                              0
# 253                              0                              0
# 276                              0                              0
#
#      album_release_date_2023-10-24
# 229                              0
# 235                              0
# 253                              0
# 276                              0
#
# [4 rows x 932 columns]
# Outliers removed for instrumentalness:
#      daily_rank  popularity  is_explicit  duration_ms  danceability  energy  \
# 3            29          61        False       165333         0.548   0.459
# 6             5          63        False       156671         0.748   0.757
# 8            20          46        False       183814         0.676   0.733
# 9            43          63        False       240008         0.631   0.822
# 12           28          85         True       231704         0.651   0.799
# ..          ...         ...          ...          ...           ...     ...
# 458          34          77        False       172105         0.739   0.668
# 469          31          96        False       187026         0.579   0.630
# 473          31          98         True       197920         0.708   0.737
# 481          31          86        False       171160         0.556   0.339
# 489           2          91         True       267194         0.787   0.621
#
#      key  loudness  mode  speechiness  ...  album_release_date_2023-10-06  \
# 3      0    -6.867     1       0.0575  ...                              0
# 6     10    -5.746     0       0.0526  ...                              1
# 8     10    -4.568     0       0.0421  ...                              0
# 9      5    -4.793     1       0.0269  ...                              0
# 12     9    -4.020     0       0.0611  ...                              0
# ..   ...       ...   ...          ...  ...                            ...
# 458    1    -7.237     0       0.0471  ...                              0
# 469    8    -7.758     1       0.0580  ...                              0
# 473    1    -4.045     1       0.0436  ...                              0
# 481    1   -11.128     0       0.0330  ...                              0
# 489    4    -5.009     0       0.0680  ...                              0
#
#      album_release_date_2023-10-07  album_release_date_2023-10-10  \
# 3                                0                              0
# 6                                0                              0
# 8                                0                              0
# 9                                0                              0
# 12                               0                              0
# ..                             ...                            ...
# 458                              0                              0
# 469                              0                              0
# 473                              0                              0
# 481                              0                              0
# 489                              0                              0
#
#      album_release_date_2023-10-12  album_release_date_2023-10-13  \
# 3                                0                              0
# 6                                0                              0
# 8                                0                              0
# 9                                0                              0
# 12                               0                              1
# ..                             ...                            ...
# 458                              0                              0
# 469                              0                              0
# 473                              0                              0
# 481                              0                              0
# 489                              0                              1
#
#      album_release_date_2023-10-16  album_release_date_2023-10-19  \
# 3                                0                              0
# 6                                0                              0
# 8                                0                              1
# 9                                0                              0
# 12                               0                              0
# ..                             ...                            ...
# 458                              0                              0
# 469                              0                              0
# 473                              0                              0
# 481                              0                              0
# 489                              0                              0
#
#      album_release_date_2023-10-20  album_release_date_2023-10-23  \
# 3                                0                              0
# 6                                0                              0
# 8                                0                              0
# 9                                0                              0
# 12                               0                              0
# ..                             ...                            ...
# 458                              0                              0
# 469                              0                              0
# 473                              0                              0
# 481                              0                              0
# 489                              0                              0
#
#      album_release_date_2023-10-24
# 3                                0
# 6                                0
# 8                                0
# 9                                0
# 12                               0
# ..                             ...
# 458                              0
# 469                              0
# 473                              0
# 481                              0
# 489                              0
#
# [85 rows x 932 columns]
# Outliers removed for liveness:
#      daily_rank  popularity  is_explicit  duration_ms  danceability  energy  \
# 4            35          95         True       212878         0.646   0.736
# 29           28          95         True       212878         0.646   0.736
# 39           47          78        False       210117         0.665   0.541
# 48           46          93         True       215466         0.855   0.678
# 73           16          71        False       154298         0.724   0.905
# 110          16          86        False       171712         0.521   0.825
# 113          19          45         True       204255         0.683   0.738
# 124          17          61        False       161800         0.650   0.507
# 143          22          61        False       131666         0.718   0.682
# 192          28          83        False       168840         0.625   0.916
# 194          38          95         True       212878         0.646   0.736
# 234          35          92         True       211141         0.546   0.846
# 262          27          88        False       153190         0.601   0.741
# 301          30          90         True       232131         0.805   0.707
# 306          35          93         True       215466         0.855   0.678
# 472          42          90         True       232131         0.805   0.707
# 477          38          85        False       157477         0.732   0.839
# 485          42          90         True       232131         0.805   0.707
#
#      key  loudness  mode  speechiness  ...  album_release_date_2023-10-06  \
# 4      5    -7.118     0       0.0449  ...                              0
# 29     5    -7.118     0       0.0449  ...                              0
# 39     3    -5.864     0       0.0861  ...                              0
# 48     1    -6.276     1       0.1890  ...                              0
# 73     8    -6.316     1       0.2320  ...                              0
# 110    8    -6.025     0       0.1260  ...                              0
# 113    0    -6.777     1       0.0315  ...                              0
# 124    5    -8.020     1       0.0533  ...                              0
# 143    1    -6.411     0       0.0329  ...                              0
# 192    6    -3.704     1       0.0461  ...                              0
# 194    5    -7.118     0       0.0449  ...                              0
# 234    5    -5.719     1       0.1810  ...                              0
# 262    2    -5.569     1       0.0478  ...                              0
# 301    6    -3.758     0       0.0353  ...                              0
# 306    1    -6.276     1       0.1890  ...                              0
# 472    6    -3.758     0       0.0353  ...                              0
# 477    9    -5.007     1       0.0345  ...                              0
# 485    6    -3.758     0       0.0353  ...                              0
#
#      album_release_date_2023-10-07  album_release_date_2023-10-10  \
# 4                                0                              0
# 29                               0                              0
# 39                               0                              0
# 48                               0                              0
# 73                               0                              0
# 110                              0                              0
# 113                              0                              0
# 124                              0                              0
# 143                              0                              0
# 192                              0                              0
# 194                              0                              0
# 234                              0                              0
# 262                              0                              0
# 301                              0                              0
# 306                              0                              0
# 472                              0                              0
# 477                              0                              0
# 485                              0                              0
#
#      album_release_date_2023-10-12  album_release_date_2023-10-13  \
# 4                                0                              0
# 29                               0                              0
# 39                               0                              0
# 48                               0                              0
# 73                               0                              0
# 110                              0                              0
# 113                              0                              0
# 124                              0                              0
# 143                              0                              0
# 192                              0                              0
# 194                              0                              0
# 234                              0                              0
# 262                              0                              0
# 301                              0                              0
# 306                              0                              0
# 472                              0                              0
# 477                              0                              0
# 485                              0                              0
#
#      album_release_date_2023-10-16  album_release_date_2023-10-19  \
# 4                                0                              0
# 29                               0                              0
# 39                               0                              0
# 48                               0                              0
# 73                               0                              0
# 110                              0                              0
# 113                              0                              0
# 124                              0                              0
# 143                              0                              0
# 192                              0                              0
# 194                              0                              0
# 234                              0                              0
# 262                              0                              0
# 301                              0                              0
# 306                              0                              0
# 472                              0                              0
# 477                              0                              0
# 485                              0                              0
#
#      album_release_date_2023-10-20  album_release_date_2023-10-23  \
# 4                                0                              0
# 29                               0                              0
# 39                               0                              0
# 48                               0                              0
# 73                               0                              0
# 110                              0                              0
# 113                              0                              0
# 124                              0                              0
# 143                              0                              0
# 192                              0                              0
# 194                              0                              0
# 234                              0                              0
# 262                              0                              0
# 301                              0                              0
# 306                              0                              0
# 472                              0                              0
# 477                              0                              0
# 485                              0                              0
#
#      album_release_date_2023-10-24
# 4                                0
# 29                               0
# 39                               0
# 48                               0
# 73                               0
# 110                              0
# 113                              0
# 124                              0
# 143                              0
# 192                              0
# 194                              0
# 234                              0
# 262                              0
# 301                              0
# 306                              0
# 472                              0
# 477                              0
# 485                              0
#
# [18 rows x 932 columns]
# Outliers removed for tempo:
#      daily_rank  popularity  is_explicit  duration_ms  danceability  energy  \
# 101          43          60        False       288099         0.481   0.901
#
#      key  loudness  mode  speechiness  ...  album_release_date_2023-10-06  \
# 101    0    -5.629     1        0.163  ...                              0
#
#      album_release_date_2023-10-07  album_release_date_2023-10-10  \
# 101                              0                              0
#
#      album_release_date_2023-10-12  album_release_date_2023-10-13  \
# 101                              0                              0
#
#      album_release_date_2023-10-16  album_release_date_2023-10-19  \
# 101                              0                              0
#
#      album_release_date_2023-10-20  album_release_date_2023-10-23  \
# 101                              0                              0
#
#      album_release_date_2023-10-24
# 101                              0
#
# [1 rows x 932 columns]

# %% [markdown]
# # Question 3

# %%
numerical_features = ['popularity', 'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']

for feature in numerical_features:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=feature, y='daily_rank', data=df)
    plt.title(f"{feature} vs daily_rank")
    plt.show()

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\cheat\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.18 in c:\users\cheat\anaconda3\lib\site-packages (from statsmodels) (1.24.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in c:\users\cheat\anaconda3\lib\site-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: pandas>=1.0 in c:\users\cheat\anaconda3\lib\site-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\cheat\anaconda3\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\cheat\anaconda3\lib\site-packages (from statsmodels) (23.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\cheat\anaconda3\lib\site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cheat\anaconda3\lib\site-packages (from pandas>=1.0->statsmodels) (2022.7)
# Requirement already satisfied: six in c:\users\cheat\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

original_df = pd.read_csv('universal_top_spotify_songs.csv', nrows=500)

results = {}

for column in original_df.columns:
    if column != "daily_rank" and original_df[column].dtype == "object" and len(original_df[column].unique()) > 2:
        formula = f"daily_rank ~ C({column})"
        model = ols(formula, data=original_df).fit()
        aov_table = sm.stats.anova_lm(model, typ=2)  
        results[column] = aov_table

for column, aov in results.items():
    print(f"\nANOVA results for variable: {column}\n")
    print(aov)
# Out:
# ANOVA results for variable: spotify_id
#
#                      sum_sq     df         F   PR(>F)
# C(spotify_id)  88720.916667  397.0  1.479789  0.00901
# Residual       15404.083333  102.0       NaN      NaN
#
# ANOVA results for variable: name
#
#                 sum_sq     df         F   PR(>F)
# C(name)   88720.916667  397.0  1.479789  0.00901
# Residual  15404.083333  102.0       NaN      NaN
#
# ANOVA results for variable: artists
#
#                  sum_sq     df         F   PR(>F)
# C(artists)  74627.48254  336.0  1.227331  0.06925
# Residual    29497.51746  163.0       NaN      NaN
#
# ANOVA results for variable: country
#
#                   sum_sq     df             F  PR(>F)
# C(country)  1.661153e-24    8.0  9.771488e-28     1.0
# Residual    9.371250e+04  441.0           NaN     NaN
#
# ANOVA results for variable: album_name
#
#                      sum_sq     df         F    PR(>F)
# C(album_name)  73914.802997  337.0  1.176151  0.120779
# Residual       30210.197003  162.0       NaN       NaN
#
# ANOVA results for variable: album_release_date
#
#                             sum_sq     df         F    PR(>F)
# C(album_release_date)  42477.59855  200.0  1.030117  0.405855
# Residual               61647.40145  299.0       NaN       NaN

# %%
import pandas as pd
from scipy.stats import chi2_contingency

original_df = pd.read_csv('universal_top_spotify_songs.csv', nrows=500)

results_chi2 = {}

for column in original_df.columns:
    if column != "daily_rank" and original_df[column].dtype == "object" and len(original_df[column].unique()) > 2:
        contingency_table = pd.crosstab(original_df[column], original_df["daily_rank"])
        chi2, p, _, _ = chi2_contingency(contingency_table)
        
        results_chi2[column] = {"Chi2 Value": chi2, "P-Value": p}

for column, chi2_result in results_chi2.items():
    print(f"\nChi-squared results for variable: {column}\n")
    print("Chi2 Value:", chi2_result["Chi2 Value"])
    print("P-Value:", chi2_result["P-Value"])
# Out:
# Chi-squared results for variable: spotify_id
#
# Chi2 Value: 19611.66666666667
# P-Value: 0.21023364685216187
#
# Chi-squared results for variable: name
#
# Chi2 Value: 19611.666666666668
# P-Value: 0.21023364685216714
#
# Chi-squared results for variable: artists
#
# Chi2 Value: 16561.86507936508
# P-Value: 0.29393495915721646
#
# Chi-squared results for variable: country
#
# Chi2 Value: 0.0
# P-Value: 1.0
#
# Chi-squared results for variable: album_name
#
# Chi2 Value: 16614.318181818184
# P-Value: 0.28772299505763305
#
# Chi-squared results for variable: album_release_date
#
# Chi2 Value: 9911.484409899045
# P-Value: 0.21241351305783088

# %%
important_features = ['daily_rank', 'popularity', 'is_explicit', 'duration_ms', 'danceability', 'energy']

cols_to_remove = [col for col in df.columns if col not in important_features]

df.drop(columns=cols_to_remove, inplace=True)

print(df.head())
# Out:
#     daily_rank  popularity  is_explicit  duration_ms  danceability  energy
# 1           16          80        False       167356         0.550   0.500
# 2            7          87         True       203894         0.758   0.703
# 7           33          72        False       190560         0.841   0.783
# 10          10          75         True       284812         0.480   0.571
# 11          31          96        False       186000         0.668   0.712

# %% [markdown]
# There's a few variables with little to no variance, which are spotify_id, name, album_name, and album_release_date

# %% [markdown]
# From the results:
#
# country in ANOVA has a p-value of 1.0, suggesting it might not be a relevant predictor for daily_rank.
# album_release_date in ANOVA has a relatively high p-value (0.405855), making it potentially less relevant in predicting daily_rank.
# country in Chi-squared also has a p-value of 1.0, further supporting that it might not be relevant.

# %% [markdown]
# There seems to be no high-correlated features that are noticable immediately by my scatter plot graphs.

# %% [markdown]
# My algorithim will not require either normalized or standardized data.

# %% [markdown]
# # Question 4

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

X = df.drop('daily_rank', axis=1) 
y = df['daily_rank']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)

print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Root Mean Squared Error: 15.19238907230522
# R-squared: -0.20707994780862538

# %% [markdown]
# Yes, the data does need to be balanced and I did use train_test_split to vaidate the result. I used the Random Forest algorithm and for evaluating the prediction model I used the Root Mean Squared Error.

# %% [markdown]
# It seems that my model failed and I believe the reason is because there were no relavant features that really helped get us down to determining the daily_rank.

# %% [markdown]
# # Question 5

# %% [markdown]
# https://github.com/Aidan56368/UWG-Project
